# %%
import pandas as pd
import numpy as np

# %%
data_path = "D:\\University\\DataScienceWorkshop\\"

# %%
train = pd.read_csv(data_path + "train_sample.csv", usecols=['ad_id','clicked'])

# %%
#1.compute ad click frequency by aggregating it's total count and sum clicks on train table
#2.normalize result to avoid corner cases distortion
#3.drop unused columns
ad_strength = train.groupby('ad_id').clicked.agg(['count','sum']).reset_index()
ad_strength['strength'] = (ad_strength['sum'] + 12 * train.clicked.mean()) / (12 + ad_likelihood['count'])
ad_strength.drop(['count', 'sum'], axis=1, inplace=True)
ad_strength.describe()
# Out:
#                ad_id       strength
# count  128782.000000  128782.000000
# mean   197071.183597       0.184574
# std    106920.552553       0.063218
# min         1.000000       0.007939
# 25%    107683.750000       0.154599
# 50%    203793.500000       0.178383
# 75%    289930.500000       0.205666
# max    378604.000000       0.760514

# %%
promoted.drop('document_id', axis = 1, inplace = True)

# %%
promoted
# Out:
#           ad_id  category_id
# 0             1         1209
# 1             1         1708
# 2             2         1505
# 3             2         1405
# 4             3         1209
# 5             3         1203
# 6             4         1205
# 7             4         1610
# 8             5         1608
# 9             5         1203
# 10            6         1513
# 11            6         1514
# 12            7         1209
# 13            7         1205
# 14            8         1611
# 15            8         1610
# 16            9         1513
# 17            9         1808
# 18           10         1505
# 19           10         1809
# 20           11         1604
# 21           11         1209
# 22           12         1506
# 23           12         1505
# 24         5183         1506
# 25         5183         1505
# 26           13         1503
# 27           13         1505
# 28       118163         1503
# 29       118163         1505
# ...         ...          ...
# ...

# %%
train = pd.read_csv("D:\\University\\DataScienceWorkshop\\clicks_train.csv")

# %%
#add number of ads on display
train_ad_count_per_display = train.groupby(['display_id'])['display_id'].agg({'ads_on_doc' : 'count'}).reset_index()
train = train.merge(train_ad_count_per_display, how = 'left', on = 'display_id')
del train_ad_count_per_display

# %%
del categories
